# %% [markdown]
# Import library and load datset

# %%
#import library
import pandas as pd

# %%
#load dataset
df=pd.read_csv('cars.csv')
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
#applying condition on series
df['Weight']>=3500
#note:I asked to print weight which is greater than 3500 and it prints true or false only when we use location only it displays from that table
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 401    False
# 402    False
# 403    False
# 404    False
# 405    False
# Name: Weight, Length: 406, dtype: bool

# %%
#Filtering rows based on conditions
df.loc[df['Weight']>=3500]
#note:we used df.loc to display weight condition from the table
# Out:
#                                       Car   MPG  Cylinders  Displacement  \
# 0               Chevrolet Chevelle Malibu  18.0        8.0         307.0
# 1                       Buick Skylark 320  15.0        8.0         350.0
# 5                        Ford Galaxie 500  15.0        8.0         429.0
# 6                        Chevrolet Impala  14.0        8.0         454.0
# 7                       Plymouth Fury iii  14.0        NaN         440.0
# ..                                    ...   ...        ...           ...
# 298         Chevrolet Malibu Classic (sw)  19.2        8.0         267.0
# 299  Chrysler Lebaron Town @ Country (sw)  18.5        8.0         360.0
# 304                    Mercedes Benz 300d  25.4        5.0         183.0
# 305                     Cadillac Eldorado  23.0        8.0         350.0
# 372                 Oldsmobile Cutlass LS  26.6        8.0         350.0
#
#      Horsepower  Weight  Acceleration  Model  Origin
# ...

# %%
#filtering rows using string value
df.loc[df['Origin']== 'US']
#note:I dislplayed the origin which has only US and I used loc funcion so it displays from the table
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 400           Chevrolet Camaro  27.0        4.0         151.0        90.0
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model Origin
# ...

# %%
#filtering rows using integer value
df.loc[df['Model']== 70]
#note:I dislplayed the model which has only 70 and I used loc funcion so it displays from the table
# Out:
#                                  Car   MPG  Cylinders  Displacement  \
# 0          Chevrolet Chevelle Malibu  18.0        8.0         307.0
# 1                  Buick Skylark 320  15.0        8.0         350.0
# 2                 Plymouth Satellite  18.0        8.0         318.0
# 3                      AMC Rebel SST  16.0        8.0         304.0
# 4                        Ford Torino  17.0        8.0         302.0
# 5                   Ford Galaxie 500  15.0        8.0         429.0
# 6                   Chevrolet Impala  14.0        8.0         454.0
# 7                  Plymouth Fury iii  14.0        NaN         440.0
# 8                   Pontiac Catalina  14.0        8.0         455.0
# 9                 AMC Ambassador DPL  15.0        8.0         390.0
# 10              Citroen DS-21 Pallas   0.0        4.0         133.0
# 11  Chevrolet Chevelle Concours (sw)   0.0        8.0         350.0
# 12                  Ford Torino (sw)   0.0        8.0         351.0
# ...
